# %% [markdown]
# # Welcome to first steps of analysis JN

# %% [markdown]
# ## Постановка задачи и выяснение общей картины.
# ### Цель этого проекта - анализ рынка труда по направленям Data Sciense и аналитики

# %%
# Common imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# from tqdm import tnrange, tqdm_notebook
# from random import random, randint

# to make this notebook's output stable across runs
np.random.seed(13)

print("Setup Complete!")
# Out:
# Setup Complete!

# %% [markdown]
# ### Этап первый: получение данных
# #### Выгрузка собранного датасета

# %%
vacancies = pd.read_csv("/home/aleksey/PycharmProjects/My_Web_Scrapper/dataset/" + 'ds_vacancies_data.csv', index_col=0).T
print("Data is ready!")
# Out:
# Data is ready!

# %%
# Посмотрим, что из себя представлет наш собранный датасет
vacancies.head()
# Out:
#                                                      0  \
# 0    Специалист по углубленной аналитике данных (Da...
# 0.1                                     Data Scientist
# 0.2                                     Data Scientist
# 0.3                                     Data Scientist
# 0.4                                     Data Scientist
#
#                                           1  \
# 0    А1. Информационные технологии, телеком
# 0.1                        НУР Телеком ОсОО
# 0.2                           ООО Артистраж
# 0.3                               ООО РАБЛЗ
# 0.4                          ООО КИБЕРБОРЕЯ
#
#                                                      2            3  \
# 0    Купаловская, Октябрьская, Минск, Интернационал...     1–3 года
# 0.1             Бишкек, улица Юсупа Абдрахманова, 170А  более 6 лет
# 0.2                                             Москва     1–3 года
# 0.3                                             Москва     1–3 года
# 0.4                                             Москва     1–3 года
#
#                                       4  \
# 0         Полная занятость, полный день
# 0.1       Полная занятость, полный день
# 0.2       Полная занятость, полный день
# 0.3  Полная занятость, удаленная работа
# 0.4       Полная занятость, полный день
#
#                                                 5  \
# 0                                  з/п не указана
# 0.1                                з/п не указана
# 0.2  от 120 000 до 170 000 руб. до вычета налогов
# 0.3  от 150 000 до 210 000 руб. до вычета налогов
# 0.4  от 120 000 до 170 000 руб. до вычета налогов
#
#                                                   6  \
# 0     Вакансия опубликована 6 октября 2020 в Минске
# 0.1  Вакансия опубликована 1 октября 2020 в Бишкеке
# 0.2   Вакансия опубликована 6 октября 2020 в Москве
# 0.3   Вакансия опубликована 7 октября 2020 в Москве
# 0.4   Вакансия опубликована 6 октября 2020 в Москве
#
#                                                      7  \
# 0    Основные задачи:\nИсследование данных из разли...
# 0.1  Задачи:\nпостроение и сопровождение платформ B...
# 0.2  Обязанности:\nОбработка и аналитика входных да...
# 0.3  Наша компания разрабатывает аналитические реше...
# 0.4  Обязанности:\nОбработка и аналитика входных да...
#
#                                                      8
# 0    SPSS\nСтатистический анализ\nStatistica\nАнали...
# 0.1          Python\nJava\nSQL\nLinux\nSCALA\nBig Data
# 0.2  Python\nR\nMachine Learning\nComputer Vision\n...
# 0.3                   Data Mining\nPython\nSQL\nPandas
# 0.4  Python\nR\nGit\nMachine Learning\nМашинное обу...

# %% [markdown]
# В целом, кусок собранного датасета выглядит вполне неплохо. Теперь надо бы привести его в адекватный вид. Зададим более осмысленные названия для столбцов. А также нормальные индексы для строк.

# %%
# Взглянем на количество вакансий
print(vacancies.shape)
# Out:
# (295, 9)

# %% [markdown]
# Почти 300 вакансий! В целом, этого должно быть достаточно для анализа.

# %%
vacancies.columns = ['vacancy_title', 'company_name', 'location', 'required_experience', 'employment_mode', 'vacancy_salary',
              'published_date', 'vacancy_description', 'vacancy_tags']

# %%
vacancies.index = [idx for idx in range(1,vacancies.shape[0]+1)]

# %%
vacancies.head(5)
# Out:
#                                        vacancy_title  \
# 1  Специалист по углубленной аналитике данных (Da...
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
#
#                              company_name  \
# 1  А1. Информационные технологии, телеком
# 2                        НУР Телеком ОсОО
# 3                           ООО Артистраж
# 4                               ООО РАБЛЗ
# 5                          ООО КИБЕРБОРЕЯ
#
#                                             location required_experience  \
# 1  Купаловская, Октябрьская, Минск, Интернационал...            1–3 года
# 2             Бишкек, улица Юсупа Абдрахманова, 170А         более 6 лет
# 3                                             Москва            1–3 года
# 4                                             Москва            1–3 года
# 5                                             Москва            1–3 года
#
#                       employment_mode  \
# 1       Полная занятость, полный день
# 2       Полная занятость, полный день
# 3       Полная занятость, полный день
# 4  Полная занятость, удаленная работа
# 5       Полная занятость, полный день
#
#                                  vacancy_salary  \
# 1                                з/п не указана
# 2                                з/п не указана
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 4  от 150 000 до 210 000 руб. до вычета налогов
# 5  от 120 000 до 170 000 руб. до вычета налогов
#
#                                    published_date  \
# 1   Вакансия опубликована 6 октября 2020 в Минске
# 2  Вакансия опубликована 1 октября 2020 в Бишкеке
# 3   Вакансия опубликована 6 октября 2020 в Москве
# 4   Вакансия опубликована 7 октября 2020 в Москве
# 5   Вакансия опубликована 6 октября 2020 в Москве
#
#                                  vacancy_description  \
# 1  Основные задачи:\nИсследование данных из разли...
# 2  Задачи:\nпостроение и сопровождение платформ B...
# 3  Обязанности:\nОбработка и аналитика входных да...
# 4  Наша компания разрабатывает аналитические реше...
# 5  Обязанности:\nОбработка и аналитика входных да...
#
#                                         vacancy_tags
# 1  SPSS\nСтатистический анализ\nStatistica\nАнали...
# 2          Python\nJava\nSQL\nLinux\nSCALA\nBig Data
# 3  Python\nR\nMachine Learning\nComputer Vision\n...
# 4                   Data Mining\nPython\nSQL\nPandas
# 5  Python\nR\nGit\nMachine Learning\nМашинное обу...

# %% [markdown]
# Уже лучше. Но всё же есть ещё одна проблема - описание вакансий и тэги на данный момент являются цельными строками, без нормальной разметки. Исправим.

# %%
vacancies.vacancy_tags = vacancies.vacancy_tags.str.split(pat="\n")
vacancies.vacancy_description = vacancies.vacancy_description.str.split(pat="\n")
vacancies.head()
# Out:
#                                        vacancy_title  \
# 1  Специалист по углубленной аналитике данных (Da...
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
#
#                              company_name  \
# 1  А1. Информационные технологии, телеком
# 2                        НУР Телеком ОсОО
# 3                           ООО Артистраж
# 4                               ООО РАБЛЗ
# 5                          ООО КИБЕРБОРЕЯ
#
#                                             location required_experience  \
# 1  Купаловская, Октябрьская, Минск, Интернационал...            1–3 года
# 2             Бишкек, улица Юсупа Абдрахманова, 170А         более 6 лет
# 3                                             Москва            1–3 года
# 4                                             Москва            1–3 года
# 5                                             Москва            1–3 года
#
#                       employment_mode  \
# 1       Полная занятость, полный день
# 2       Полная занятость, полный день
# 3       Полная занятость, полный день
# 4  Полная занятость, удаленная работа
# 5       Полная занятость, полный день
#
#                                  vacancy_salary  \
# 1                                з/п не указана
# 2                                з/п не указана
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 4  от 150 000 до 210 000 руб. до вычета налогов
# 5  от 120 000 до 170 000 руб. до вычета налогов
#
#                                    published_date  \
# 1   Вакансия опубликована 6 октября 2020 в Минске
# 2  Вакансия опубликована 1 октября 2020 в Бишкеке
# 3   Вакансия опубликована 6 октября 2020 в Москве
# 4   Вакансия опубликована 7 октября 2020 в Москве
# 5   Вакансия опубликована 6 октября 2020 в Москве
#
#                                  vacancy_description  \
# 1  [Основные задачи:, Исследование данных из разл...
# 2  [Задачи:, построение и сопровождение платформ ...
# 3  [Обязанности:, Обработка и аналитика входных д...
# 4  [Наша компания разрабатывает аналитические реш...
# 5  [Обязанности:, Обработка и аналитика входных д...
#
#                                         vacancy_tags
# 1  [SPSS, Статистический анализ, Statistica, Анал...
# 2        [Python, Java, SQL, Linux, SCALA, Big Data]
# 3  [Python, R, Machine Learning, Computer Vision,...
# 4                 [Data Mining, Python, SQL, Pandas]
# 5  [Python, R, Git, Machine Learning, Машинное об...

# %% [markdown]
# Вот теперь намного лучше! С этим уже можно работать.
#
# Чтобы не испортить полученный датасет, сделаем его копию и работать далее будем с ней.

# %%
vacancies_df = vacancies.copy()

# %%
vacancies_df.head()
# Out:
#                                        vacancy_title  \
# 1  Специалист по углубленной аналитике данных (Da...
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
#
#                              company_name  \
# 1  А1. Информационные технологии, телеком
# 2                        НУР Телеком ОсОО
# 3                           ООО Артистраж
# 4                               ООО РАБЛЗ
# 5                          ООО КИБЕРБОРЕЯ
#
#                                             location required_experience  \
# 1  Купаловская, Октябрьская, Минск, Интернационал...            1–3 года
# 2             Бишкек, улица Юсупа Абдрахманова, 170А         более 6 лет
# 3                                             Москва            1–3 года
# 4                                             Москва            1–3 года
# 5                                             Москва            1–3 года
#
#                       employment_mode  \
# 1       Полная занятость, полный день
# 2       Полная занятость, полный день
# 3       Полная занятость, полный день
# 4  Полная занятость, удаленная работа
# 5       Полная занятость, полный день
#
#                                  vacancy_salary  \
# 1                                з/п не указана
# 2                                з/п не указана
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 4  от 150 000 до 210 000 руб. до вычета налогов
# 5  от 120 000 до 170 000 руб. до вычета налогов
#
#                                    published_date  \
# 1   Вакансия опубликована 6 октября 2020 в Минске
# 2  Вакансия опубликована 1 октября 2020 в Бишкеке
# 3   Вакансия опубликована 6 октября 2020 в Москве
# 4   Вакансия опубликована 7 октября 2020 в Москве
# 5   Вакансия опубликована 6 октября 2020 в Москве
#
#                                  vacancy_description  \
# 1  [Основные задачи:, Исследование данных из разл...
# 2  [Задачи:, построение и сопровождение платформ ...
# 3  [Обязанности:, Обработка и аналитика входных д...
# 4  [Наша компания разрабатывает аналитические реш...
# 5  [Обязанности:, Обработка и аналитика входных д...
#
#                                         vacancy_tags
# 1  [SPSS, Статистический анализ, Statistica, Анал...
# 2        [Python, Java, SQL, Linux, SCALA, Big Data]
# 3  [Python, R, Machine Learning, Computer Vision,...
# 4                 [Data Mining, Python, SQL, Pandas]
# 5  [Python, R, Git, Machine Learning, Машинное об...

# %%
vacancies_df.tail()
# Out:
#                                          vacancy_title  \
# 291                                     Data Scientist
# 292  Стажер Data Scientist, Группа улучшения бизнес...
# 293                              Junior Data Scientist
# 294  Data Scientist на проекты по созданию графа св...
# 295  Data Scientist – моделирование кредитных риско...
#
#                              company_name  \
# 291                              Тинькофф
# 292                    EY (Эрнст энд Янг)
# 293                                   АДВ
# 294                        Банк ВТБ (ПАО)
# 295  «Газпромбанк» (Акционерное общество)
#
#                                               location required_experience  \
# 291                                             Москва        не требуется
# 292  Павелецкая, Москва, Садовническая набережная, ...        не требуется
# 293                                             Москва        не требуется
# 294                                             Москва            1–3 года
# 295                                             Москва            1–3 года
#
#                      employment_mode  vacancy_salary  \
# 291  Полная занятость, гибкий график  з/п не указана
# 292    Полная занятость, полный день  з/п не указана
# 293    Полная занятость, полный день  з/п не указана
# 294    Полная занятость, полный день  з/п не указана
# 295    Полная занятость, полный день  з/п не указана
#
#                                       published_date  \
# 291  Вакансия опубликована 17 сентября 2020 в Москве
# 292  Вакансия опубликована 15 сентября 2020 в Москве
# 293  Вакансия опубликована 10 сентября 2020 в Москве
# 294    Вакансия опубликована 6 октября 2020 в Москве
# 295    Вакансия опубликована 7 октября 2020 в Москве
#
#                                    vacancy_description  \
# 291  [Команда рекомендательных систем Тинькофф ищет...
# 292  [Специалисты сбора и аналитической обработки д...
# 293  [В сетевое рекламное агентство, входящее в одн...
# 294  [В управление разработки моделей для корпорати...
# 295  [Обязанности:, Полный цикл разработки моделей:...
#
#                                           vacancy_tags
# 291                                           [Python]
# 292  [Python, Data Mining, Английский язык, SQL, Ст...
# 293                                                NaN
# 294  [Python, Математическая статистика, Data Minin...
# 295  [Python, Математическое моделирование, Математ...

# %% [markdown]
# #### Посмотрим на наши данные повнимательнее

# %%
vacancies_df.describe()
# Out:
#          vacancy_title        company_name location required_experience  \
# count              295                 295      295                 295
# unique             174                 168      134                   4
# top     Data Scientist  Сбер для экспертов   Москва            1–3 года
# freq                66                  36       78                 140
#
#                       employment_mode  vacancy_salary  \
# count                             295             295
# unique                              9              27
# top     Полная занятость, полный день  з/п не указана
# freq                              255             263
#
#                                        published_date  \
# count                                             295
# unique                                            110
# top     Вакансия опубликована 6 октября 2020 в Москве
# freq                                               29
#
#                                       vacancy_description vacancy_tags
# count                                                 295          209
# unique                                                259          172
# top     [Мы ищем специалистов по машинному обучению и ...     [Python]
# freq                                                    6            6

# %% [markdown]
# Интересно! Что можно сказать точно:
# 1) DS очень нужны в Сбер;
#
# 2) Люди нужны преимущественно в Москве (ну а как же, где же ещё?);
#
# 3) Для работадателя интересна схема работы - полная занятость на полный день;
#
# 4) Зарплаты указывать не хотят.

# %% [markdown]
# Проверить стоит много чего. Но для начала:
# 1) Вакансии с одинаковыми зарплатами и описанием - что это такое;
#
# 2) В основном ищут людей со средним опытом;

# %%
# Посмотрим, что там у нас по зарплатам! 
vacancies_df.vacancy_salary.value_counts()
# Out:
# з/п не указана                                  263
# от 200 000 до 280 000 руб. до вычета налогов      3
# от 150 000 руб. на руки                           2
# от 180 000 руб. на руки                           2
# от 120 000 до 170 000 руб. до вычета налогов      2
# до 130 000 руб. до вычета налогов                 2
# от 150 000 до 210 000 руб. до вычета налогов      1
# от 83 000 руб. до вычета налогов                  1
# от 65 000 руб. до вычета налогов                  1
# до 405 000 KZT до вычета налогов                  1
# до 100 000 руб. до вычета налогов                 1
# от 180 000 до 200 000 руб. на руки                1
# от 120 000 до 160 000 руб. на руки                1
# от 120 000 до 150 000 руб. на руки                1
# от 200 000 руб. до вычета налогов                 1
# до 150 000 руб. на руки                           1
# от 200 000 руб. на руки                           1
# от 75 000 руб. до вычета налогов                  1
# от 60 000 руб. на руки                            1
# до 700 000 KZT на руки                            1
# от 140 000 руб. на руки                           1
# до 500 000 руб. до вычета налогов                 1
# до 200 000 руб. на руки                           1
# от 110 000 руб. на руки                           1
# до 190 000 руб. до вычета налогов                 1
# от 85 000 руб. до вычета налогов                  1
# от 80 000 до 120 000 руб. на руки                 1
# Name: vacancy_salary, dtype: int64

# %% [markdown]
# Не густо - информации по зарплатам в явном виде исчезающе мало.

# %% [markdown]
# Забавно. А что это у нас за вакансии такие, в которых установленные зарплаты совпадают?

# %%
vacancies_df[vacancies_df.vacancy_salary == "от 200 000 до 280 000 руб. до вычета налогов"]
# Out:
#                       vacancy_title company_name         location  \
# 134  Senior Data Scientist (remote)      Agiloft      Новосибирск
# 139  Senior Data Scientist (remote)      Agiloft           Москва
# 141  Senior Data Scientist (remote)      Agiloft  Санкт-Петербург
#
#     required_experience                employment_mode  \
# 134             3–6 лет  Полная занятость, полный день
# 139             3–6 лет  Полная занятость, полный день
# 141             3–6 лет  Полная занятость, полный день
#
#                                    vacancy_salary  \
# 134  от 200 000 до 280 000 руб. до вычета налогов
# 139  от 200 000 до 280 000 руб. до вычета налогов
# 141  от 200 000 до 280 000 руб. до вычета налогов
#
#                                         published_date  \
# 134  Вакансия опубликована 20 сентября 2020 в Новос...
# 139    Вакансия опубликована 20 сентября 2020 в Москве
# 141  Вакансия опубликована 18 сентября 2020 в Санкт...
#
#                                    vacancy_description  \
# 134  [Position overview, We are looking for an expe...
# 139  [Position overview, We are looking for an expe...
# 141  [Position overview, We are looking for an expe...
#
#                                           vacancy_tags
# 134  [Python, Английский язык, MATLAB, MS PowerPoin...
# 139  [Python, Английский язык, MATLAB, MS PowerPoin...
# 141  [Python, Английский язык, MATLAB, MS PowerPoin...

# %%
vacancies_df.loc[[134,139,141], ["vacancy_title", "company_name", "required_experience", "vacancy_description", 
                                 "vacancy_tags"]]
# Out:
#                       vacancy_title company_name required_experience  \
# 134  Senior Data Scientist (remote)      Agiloft             3–6 лет
# 139  Senior Data Scientist (remote)      Agiloft             3–6 лет
# 141  Senior Data Scientist (remote)      Agiloft             3–6 лет
#
#                                    vacancy_description  \
# 134  [Position overview, We are looking for an expe...
# 139  [Position overview, We are looking for an expe...
# 141  [Position overview, We are looking for an expe...
#
#                                           vacancy_tags
# 134  [Python, Английский язык, MATLAB, MS PowerPoin...
# 139  [Python, Английский язык, MATLAB, MS PowerPoin...
# 141  [Python, Английский язык, MATLAB, MS PowerPoin...

# %%
vacancies_df.loc[134].vacancy_description == vacancies_df.loc[139].vacancy_description == vacancies_df.loc[141].vacancy_description
# Out:
# True

# %% [markdown]
# Да, это одна и та же вакансия, по сути.
#
# Окей, едем дальше.

# %%
vacancies_df[vacancies_df.vacancy_salary == "от 120 000 до 170 000 руб. до вычета налогов"]
# Out:
#     vacancy_title    company_name location required_experience  \
# 3  Data Scientist   ООО Артистраж   Москва            1–3 года
# 5  Data Scientist  ООО КИБЕРБОРЕЯ   Москва            1–3 года
#
#                  employment_mode  \
# 3  Полная занятость, полный день
# 5  Полная занятость, полный день
#
#                                  vacancy_salary  \
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 5  от 120 000 до 170 000 руб. до вычета налогов
#
#                                   published_date  \
# 3  Вакансия опубликована 6 октября 2020 в Москве
# 5  Вакансия опубликована 6 октября 2020 в Москве
#
#                                  vacancy_description  \
# 3  [Обязанности:, Обработка и аналитика входных д...
# 5  [Обязанности:, Обработка и аналитика входных д...
#
#                                         vacancy_tags
# 3  [Python, R, Machine Learning, Computer Vision,...
# 5  [Python, R, Git, Machine Learning, Машинное об...

# %%
for e1 in vacancies_df.loc[3].vacancy_description:
    for e2 in vacancies_df.loc[5].vacancy_description:
        if e1 == e2:
            print(e1)
# Out:
# Обязанности:
# Обработка и аналитика входных данных, их дальнейшая визуализация;
# Обработка разовых запросов;
# Разработка методик расчета для нестандартных показателей работы проектов;
# Построение и контроль работы обучаемой модели для обработки входящих данных;
# Построение системы для выявления аномалий в полученных данных;
# Требования:
# Опыт работы от 1 года
# R или Python;
# Опыт работы по анализу данных;
# Знание и понимание алгоритмов машинного обучения;
# Знание и понимание математического моделирования и математического анализа;
# Опыт работы с различными базами данных;
# Технический английский
# Условия:
# График 5/2, 11:00-20:00

# %% [markdown]
# Во дела! Компании разные, а описания почти одинаковые. Да и вообще вакансии уж очень подозрительно похожи.

# %%
vacancies_df[vacancies_df.vacancy_salary == "от 180 000 руб. на руки"]
# Out:
#                               vacancy_title company_name  \
# 52              Data Scientist (Azure Team)      SEMrush
# 131  ML Engineer / Data Scientist (DS Team)      SEMrush
#
#                                               location required_experience  \
# 52   Московские ворота, Санкт-Петербург, Заставская...            1–3 года
# 131  Московские ворота, Санкт-Петербург, Заставская...            1–3 года
#
#                    employment_mode           vacancy_salary  \
# 52   Полная занятость, полный день  от 180 000 руб. на руки
# 131  Полная занятость, полный день  от 180 000 руб. на руки
#
#                                         published_date  \
# 52   Вакансия опубликована 1 октября 2020 в Санкт-П...
# 131  Вакансия опубликована 25 сентября 2020 в Санкт...
#
#                                    vacancy_description  \
# 52   [SEMrush – продуктовая IT-компания. С 2008 год...
# 131  [SEMrush – продуктовая IT-компания. С 2008 год...
#
#                                    vacancy_tags
# 52                    [Python, Linux, Git, SQL]
# 131  [Python, Git, SQL, Английский язык, Spark]

# %% [markdown]
# Разные, однако. Хотя одна и та же компания. Разные отделы/команды.

# %%
vacancies_df[vacancies_df.vacancy_salary == "до 130 000 руб. до вычета налогов"]
# Out:
#                                          vacancy_title         company_name  \
# 259  Senior Data Scientist (обработка текстов, маши...  ГК «ВИЗАВИ Консалт»
# 268  Senior Data Scientist (обработка текстов, маши...  ГК «ВИЗАВИ Консалт»
#
#     location required_experience                employment_mode  \
# 259   Москва            1–3 года  Полная занятость, полный день
# 268     Сочи            1–3 года  Полная занятость, полный день
#
#                         vacancy_salary  \
# 259  до 130 000 руб. до вычета налогов
# 268  до 130 000 руб. до вычета налогов
#
#                                       published_date  \
# 259  Вакансия опубликована 18 сентября 2020 в Москве
# 268    Вакансия опубликована 14 сентября 2020 в Сочи
#
#                                    vacancy_description  \
# 259  [R&D крупного НПЦ приглашает к себе в команду ...
# 268  [R&D крупного НПЦ приглашает к себе в команду ...
#
#                                  vacancy_tags
# 259  [Английский — B1 — Средний, Python, SQL]
# 268  [Английский — B1 — Средний, Python, SQL]

# %%
vacancies_df.loc[259].vacancy_description == vacancies_df.loc[268].vacancy_description
# Out:
# True

# %% [markdown]
# Одна и та же вакансия.

# %% [markdown]
# Ну, и последняя подозрительная парочка.

# %%
vacancies_df[vacancies_df.vacancy_salary == "от 150 000 руб. на руки"]
# Out:
#                                   vacancy_title           company_name  \
# 14   Data Scientist / Machine Learning Engineer  Web Interactive World
# 174                              Data Scientist           Antal Russia
#
#                                               location required_experience  \
# 14   Кузнецкий мост, Лубянка, Площадь Революции, Те...            1–3 года
# 174           Тверская, Москва, Трехпрудный, 9, стр.1б            1–3 года
#
#                    employment_mode           vacancy_salary  \
# 14   Полная занятость, полный день  от 150 000 руб. на руки
# 174  Полная занятость, полный день  от 150 000 руб. на руки
#
#                                       published_date  \
# 14     Вакансия опубликована 6 октября 2020 в Москве
# 174  Вакансия опубликована 16 сентября 2020 в Москве
#
#                                    vacancy_description  \
# 14   [Приглашаем специалиста по Data Science для ра...
# 174  [We are looking for a Data Scientist for our c...
#
#                                           vacancy_tags
# 14                                                 NaN
# 174  [Python, SQL, R, Big Data, Data Analysis, Busi...

# %% [markdown]
# Однако-однако! Ну вот так вот совпало, что зарплаты одинаковые. Что уж поделать?

# %%
h = vacancies_df.groupby(["required_experience", "employment_mode"]).aggregate({"vacancy_title" : "count"})

# %%
h
# Out:
#                                                                         vacancy_title
# required_experience employment_mode
# 1–3 года            Полная занятость, гибкий график                                 6
#                     Полная занятость, полный день                                 127
#                     Полная занятость, удаленная работа                              4
#                     Проектная работа/разовое задание, удаленная работа              1
#                     Частичная занятость, удаленная работа                           2
# 3–6 лет             Полная занятость, гибкий график                                11
#                     Полная занятость, полный день                                  81
#                     Полная занятость, удаленная работа                              3
# более 6 лет         Полная занятость, гибкий график                                 5
#                     Полная занятость, полный день                                  16
# не требуется        Полная занятость, гибкий график                                 2
#                     Полная занятость, полный день                                  31
#                     Стажировка, гибкий график                                       3
#                     Стажировка, полный день                                         1
#                     Стажировка, удаленная работа                                    1
#                     Частичная занятость, гибкий график                              1

# %%
h.hist()
# Out:
# array([[<AxesSubplot:title={'center':'vacancy_title'}>]], dtype=object)
